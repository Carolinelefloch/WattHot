# %%
# %run houseLoad.py
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /Users/Tak/Project/solfox/lib/houseLoad.py in <module>()
#       6 import sqlite3
#       7
# ----> 8 conn=sqlite3.connect('..db/Household.db')
#       9 cur = conn.cursor()
#      10 Def_Load=pd.read_sql('SELECT * FROM Deferred_Load',conn)
#
# OperationalError: unable to open database file

# %% [markdown]
# ### Small Household(Flat) Case with swimming pump

# %%
################Modeling Input####################
N_day=1;N_night=1;N_room=1;Ls_App=[1,1,1,1,1,0]                 	#The Input here shouble be achieved from Website
################################################## 

Cust_Profile, Deferred_Matrix=get_household_load_profile(N_room, N_day,N_night,Ls_App)

# %%
#Print the Deferred Load
#Each Plot represent Dishwasher, Clothes Washed, and Dryer
# %matplotlib inline
for i in range(len(Deferred_Matrix)):
    plt.plot(Deferred_Matrix[i])
    plt.figure()

# %%
#Print the Baseline Results
plt.plot(Cust_Profile)

# %% [markdown]
# ### Small Household Case(Flat) without swimming pump

# %%
################Modeling Input####################
N_day=1;N_night=1;N_room=1;Ls_App=[1,1,1,1,0,0]                 	#The Input here shouble be achieved from Website
################################################## 
Cust_Profile, Deferred_Matrix=get_household_load_profile(N_room, N_day,N_night,Ls_App)

# %%
#Print the Deferred Load
#Each Plot represent Dishwasher, Clothes Washed, and Dryer
# %matplotlib inline
for i in range(len(Deferred_Matrix)):
    plt.plot(Deferred_Matrix[i])
    plt.figure()

# %%
#Print the Baseline Results
plt.plot(Cust_Profile)

# %% [markdown]
# ### Day Case that No.day>1 and No. ev<=3

# %%
################Modeling Input####################
N_day=2;N_night=3;N_room=1;Ls_App=[1,1,1,1,0,0]                 	#The Input here shouble be achieved from Website
################################################## 
Cust_Profile, Deferred_Matrix=get_household_load_profile(N_room, N_day,N_night,Ls_App)
#Print the Deferred Load
#Each Plot represent Dishwasher, Clothes Washed, and Dryer
# %matplotlib inline
for i in range(len(Deferred_Matrix)):
    plt.plot(Deferred_Matrix[i])
    plt.figure()
    #Print the Baseline Results
plt.plot(Cust_Profile)

# %% [markdown]
# ### Double Peak Case that No.day>1 and No. ev>3

# %%
################Modeling Input####################
N_day=2;N_night=5;N_room=1;Ls_App=[1,1,1,1,0,0]                 	#The Input here shouble be achieved from Website
################################################## 
Cust_Profile, Deferred_Matrix=get_household_load_profile(N_room, N_day,N_night,Ls_App)
#Print the Deferred Load
#Each Plot represent Dishwasher, Clothes Washed, and Dryer
# %matplotlib inline
for i in range(len(Deferred_Matrix)):
    plt.plot(Deferred_Matrix[i])
    plt.figure()
    #Print the Baseline Results
plt.plot(Cust_Profile)

# %% [markdown]
# ### No day=0;HVAC and Dish=0 and No. ev<=3 case(Flat)

# %%
################Modeling Input####################
N_day=0;N_night=3;N_room=1;Ls_App=[1,0,1,1,0,0]                 	#The Input here shouble be achieved from Website
################################################## 
Cust_Profile, Deferred_Matrix=get_household_load_profile(N_room, N_day,N_night,Ls_App)
#Print the Deferred Load
#Each Plot represent Dishwasher, Clothes Washed, and Dryer
# %matplotlib inline
for i in range(len(Deferred_Matrix)):
    plt.plot(Deferred_Matrix[i])
    plt.figure()
    #Print the Baseline Results
plt.plot(Cust_Profile)

# %% [markdown]
# ### N0. day=0 No. EV>3(Single Peak Case)

# %%
################Modeling Input####################
N_day=0;N_night=4;N_room=1;Ls_App=[1,1,1,1,0,0]
################################################## 
Cust_Profile, Deferred_Matrix=get_household_load_profile(N_room, N_day,N_night,Ls_App)
#Print the Deferred Load
#Each Plot represent Dishwasher, Clothes Washed, and Dryer
# %matplotlib inline
for i in range(len(Deferred_Matrix)):
    plt.plot(Deferred_Matrix[i])
    plt.figure()
    #Print the Baseline Results
plt.plot(Cust_Profile)

# %% [markdown]
# ### Four Profile without Deferred Load

# %%
#Flat
N_day=1;N_night=1;N_room=1;Ls_App=[0,0,0,0,0,0]
Cust_Profile, Deferred_Matrix=get_household_load_profile(N_room, N_day,N_night,Ls_App)
plt.plot(Cust_Profile)
#Single Peak
N_day=0;N_night=4;N_room=2;Ls_App=[0,0,0,0,0,0]
Cust_Profile, Deferred_Matrix=get_household_load_profile(N_room, N_day,N_night,Ls_App)
plt.figure()
plt.plot(Cust_Profile)
#Day
N_day=2;N_night=3;N_room=2;Ls_App=[0,0,0,0,0,0]
Cust_Profile, Deferred_Matrix=get_household_load_profile(N_room, N_day,N_night,Ls_App)
plt.figure()
plt.plot(Cust_Profile)
#Double Peak
N_day=5;N_night=5;N_room=2;Ls_App=[0,0,0,0,0,0]
Cust_Profile, Deferred_Matrix=get_household_load_profile(N_room, N_day,N_night,Ls_App)
plt.figure()
plt.plot(Cust_Profile)
